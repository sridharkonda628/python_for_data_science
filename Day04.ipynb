# %% [markdown]
# <a href="https://colab.research.google.com/github/sridharkonda628/python_for_data_science/blob/main/Day04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
import numpy as np

# %%
arr=np.array([1,2,3,45,56])

# %%
print(arr)
# Out:
# [ 1  2  3 45 56]

# %%
dfs = pd.Series(arr)

# %%
dfs
# Out:
# 0     1
# 1     2
# 2     3
# 3    45
# 4    56
# dtype: int64

# %%
data={'Name':['sid','john','denny','motu','chotu'],'Age':[12,14,15,18] }

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#     Name  Age
# 0    sid   12
# 1   john   14
# 2  denny   15
# 3   motu   15
# 4  chotu   18

# %%
df.head()
# Out:
#     Name  Age
# 0    sid   12
# 1   john   14
# 2  denny   15
# 3   motu   15
# 4  chotu   18

# %%
df.tail()
# Out:
#     Name  Age
# 0    sid   12
# 1   john   14
# 2  denny   15
# 3   motu   15
# 4  chotu   18

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      object
#  1   Age     5 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 208.0+ bytes

# %%
#it works on numerical column only
df.describe()
# Out:
#              Age
# count   5.000000
# mean   14.800000
# std     2.167948
# min    12.000000
# 25%    14.000000
# 50%    15.000000
# 75%    15.000000
# max    18.000000

# %%
#for choosing 1st row
df[0:1]
# Out:
#   Name  Age
# 0  sid   12

# %%
df.iloc[0:2]
# Out:
#    Name  Age
# 0   sid   12
# 1  john   14

# %%
df1=df.copy()

# %%
df1
# Out:
#     Name  Age
# 0    sid   12
# 1   john   14
# 2  denny   15
# 3   motu   15
# 4  chotu   18

# %%
df = pd.read_csv('/content/spotify-2023.csv',encoding='ISO-8859-1')

# %%
df.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
df.tail()
# Out:
#                     track_name      artist(s)_name  artist_count  \
# 948               My Mind & Me        Selena Gomez             1
# 949  Bigger Than The Whole Sky        Taylor Swift             1
# 950       A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951              En La De Ella  Feid, Sech, Jhayco             3
# 952                      Alone           Burna Boy             1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# 948           2022              11             3                   953
# 949           2022              10            21                  1180
# 950           2022              11             3                   573
# 951           2022              10            20                  1320
# 952           2022              11             4                   782
#
#      in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
#displays no of rows & cols
df.shape
# Out:
# (953, 24)

# %%
df.columns
# Out:
# Index(['track_name', 'artist(s)_name', 'artist_count', 'released_year',
#        'released_month', 'released_day', 'in_spotify_playlists',
#        'in_spotify_charts', 'streams', 'in_apple_playlists', 'in_apple_charts',
#        'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts', 'bpm',
#        'key', 'mode', 'danceability_%', 'valence_%', 'energy_%',
#        'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%'],
#       dtype='object')

# %%
df.drop( ['in_apple_charts',
       'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts', 'bpm',
       'key', 'mode', 'danceability_%', 'valence_%', 'energy_%',
       'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%'],axis=1
     )
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %%
pd.DataFrame(df['artist(s)_name'].str.split(',').sum()).value_counts
# Out:
# <bound method DataFrame.value_counts of                    0
# 0              Latto
# 1          Jung Kook
# 2        Myke Towers
# 3     Olivia Rodrigo
# 4       Taylor Swift
# ...              ...
# 1477    Paulo Londra
# 1478            Feid
# 1479            Sech
# 1480          Jhayco
# 1481       Burna Boy
#
# [1482 rows x 1 columns]>

# %%
#sorts by asc order
df.sort_values(by='streams')
# Out:
#                                   track_name      artist(s)_name  \
# 301  Arcï¿½ï¿½ngel: Bzrp Music Sessions, Vol  Arcangel, Bizarrap
# 500                               ýýýabcdefu               Gayle
# 515                             Best Friends          The Weeknd
# 744                                 Right On            Lil Baby
# 366                                  Revenge        XXXTENTACION
# ..                                       ...                 ...
# 455                           Seek & Destroy                 SZA
# 253                            Glimpse of Us                Joji
# 625                                   Arcade     Duncan Laurence
# 33                                 Anti-Hero        Taylor Swift
# 574      Love Grows (Where My Rosemary Goes)   Edison Lighthouse
#
#      artist_count  released_year  released_month  released_day  \
# 301             2           2023               3            22
# ...

# %%
#sorting in desc order
df.sort_values(by='streams',ascending=False)
# Out:
#                                   track_name      artist(s)_name  \
# 574      Love Grows (Where My Rosemary Goes)   Edison Lighthouse
# 33                                 Anti-Hero        Taylor Swift
# 625                                   Arcade     Duncan Laurence
# 253                            Glimpse of Us                Joji
# 455                           Seek & Destroy                 SZA
# ..                                       ...                 ...
# 366                                  Revenge        XXXTENTACION
# 744                                 Right On            Lil Baby
# 515                             Best Friends          The Weeknd
# 500                               ýýýabcdefu               Gayle
# 301  Arcï¿½ï¿½ngel: Bzrp Music Sessions, Vol  Arcangel, Bizarrap
#
#      artist_count  released_year  released_month  released_day  \
# 574             1           1970               1             1
# ...

# %%
df.to_csv()
# Out:
# ',track_name,artist(s)_name,artist_count,released_year,released_month,released_day,in_spotify_playlists,in_spotify_charts,streams,in_apple_playlists,in_apple_charts,in_deezer_playlists,in_deezer_charts,in_shazam_charts,bpm,key,mode,danceability_%,valence_%,energy_%,acousticness_%,instrumentalness_%,liveness_%,speechiness_%\n0,Seven (feat. Latto) (Explicit Ver.),"Latto, Jung Kook",2,2023,7,14,553,147,141381703,43,263,45,10,826,125,B,Major,80,89,83,31,0,8,4\n1,LALA,Myke Towers,1,2023,3,23,1474,48,133716286,48,126,58,14,382,92,C#,Major,71,61,74,7,0,10,4\n2,vampire,Olivia Rodrigo,1,2023,6,30,1397,113,140003974,94,207,91,14,949,138,F,Major,51,32,53,17,0,31,6\n3,Cruel Summer,Taylor Swift,1,2019,8,23,7858,100,800840817,116,207,125,12,548,170,A,Major,55,58,72,11,0,11,15\n4,WHERE SHE GOES,Bad Bunny,1,2023,5,18,3133,50,303236322,84,133,87,15,425,144,A,Minor,65,23,80,14,63,11,6\n5,Sprinter,"Dave, Central Cee",2,2023,6,1,2186,91,183706234,67,213,88,17,946,141,C#,Major,92,66,58,19,0,8,24\n6,Ella 
# ...

# %%
df.to_csv('final.csv')

# %%
#to find null values or not
df.isnull()
# Out:
#      track_name  artist(s)_name  artist_count  released_year  released_month  \
# 0         False           False         False          False           False
# 1         False           False         False          False           False
# 2         False           False         False          False           False
# 3         False           False         False          False           False
# 4         False           False         False          False           False
# ..          ...             ...           ...            ...             ...
# 948       False           False         False          False           False
# 949       False           False         False          False           False
# 950       False           False         False          False           False
# 951       False           False         False          False           False
# 952       False           False         False          False           False
#
# ...

# %%
#gives exact no of null vals in particular col
df.isnull().sum()
# Out:
# track_name               0
# artist(s)_name           0
# artist_count             0
# released_year            0
# released_month           0
# released_day             0
# in_spotify_playlists     0
# in_spotify_charts        0
# streams                  0
# in_apple_playlists       0
# in_apple_charts          0
# in_deezer_playlists      0
# in_deezer_charts         0
# in_shazam_charts        50
# bpm                      0
# key                     95
# mode                     0
# danceability_%           0
# valence_%                0
# energy_%                 0
# acousticness_%           0
# instrumentalness_%       0
# liveness_%               0
# speechiness_%            0
# dtype: int64

# %%
df.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...
